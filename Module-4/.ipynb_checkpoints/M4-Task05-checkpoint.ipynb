# %% [markdown]
# #  Speech Emotion Classification Using LSTM

# %% [markdown]
# ### Import Required Libraries

# %%
import os
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### Dataset Path

# %%
dataset_path = r"C:\Users\acer\Documents\AIML-Assessment\Module-4\Audio"

# %% [markdown]
# ### Emotion Mapping

# %%
emotion_names = [
    'neutral',
    'calm',
    'happy',
    'sad',
    'angry',
    'fearful',
    'disgust',
    'surprised'
]
emotion_dict = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised"
}

# %% [markdown]
# ### Feature Extraction Function

# %%
def extract_mfcc(file_path, n_mfcc=40):
    audio, sr = librosa.load(file_path, sr=None)
    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=sr,
        n_mfcc=n_mfcc
    )
    return mfcc.T

# %% [markdown]
# ### Read Dataset and Extract Features

# %%
x = []
y = []
for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.endswith("wav"):
            emotion_code = file.split("-")[2]
            if emotion_code in emotion_dict:
                emotion = emotion_dict[emotion_code]
                file_path = os.path.join(root, file)
                features = extract_mfcc(file_path)
                x.append(features)
                y.append(emotion)

# %% [markdown]
# ### Check Dataset Size

# %%
print("Number of samples: ",len(x))
print("Number of labels: ",len(y))
# Out:
# Number of samples:  1440
# Number of labels:  1440

# %% [markdown]
# ### Class Distribution

# %%
pd.Series(y).value_counts().plot(kind="bar")
plt.title("Emotion Distribution")
plt.show()

# %% [markdown]
# ### Pad Sequences

# %%
x = pad_sequences(x, maxlen=200, padding='post', truncating='post', dtype='float32')

# %% [markdown]
# ### Convert to Numpy Array

# %%
x = np.array(x)
print(x.shape)
# Out:
# (1440, 200, 40)

# %%
encoder = LabelEncoder()

y = encoder.fit_transform(y)

y = to_categorical(y)

print(y.shape)
# Out:
# (1440, 8)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify = y
)

# %% [markdown]
# ### Build LSTM Model

# %%
model = Sequential()
model.add(
    LSTM(
        128,
        return_sequences=True,
        input_shape=(x.shape[1], x.shape[2])
    )
)
model.add(Dropout(0.3))
model.add(LSTM(64))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dense(len(emotion_dict), activation='softmax'))
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 200, 128)       │        86,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 140,616 (549.28 KB)
#  Trainable params: 140,616 (549.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ### Train Model

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 232ms/step - accuracy: 0.1737 - loss: 2.0620 - val_accuracy: 0.1775 - val_loss: 2.0162
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.2682 - loss: 1.9228 - val_accuracy: 0.3290 - val_loss: 1.7629
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.3084 - loss: 1.7357 - val_accuracy: 0.3463 - val_loss: 1.6715
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 214ms/step - accuracy: 0.3366 - loss: 1.7022 - val_accuracy: 0.3636 - val_loss: 1.6695
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.3779 - loss: 1.6110 - val_accuracy: 0.4199 - val_loss: 1.5143
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.4191 - loss: 1.5541 - val_accuracy: 0.4156 - val_loss: 1.5259
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 205ms/step - accuracy: 0.4354 - loss: 1.4904 - val_accuracy: 0.4589 - val_loss: 1.4801
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.4647 - loss: 1.4242 - val_accuracy: 0.4286 - val_loss: 1.5578
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.4908 - loss: 1.3613 - val_accuracy: 0.4459 - val_loss: 1.4434
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - accuracy: 0.5027 - loss: 1.3339 - val_accuracy: 0.4026 - val_loss: 1.5584
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.5071 - loss: 1.3008 - val_accuracy: 0.4416 - val_loss: 1.5549
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.5353 - loss: 1.2614 - val_accuracy: 0.4719 - val_loss: 1.4433
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - accuracy: 0.5396 - loss: 1.2273 - val_accuracy: 0.4805 - val_loss: 1.4853
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.5874 - loss: 1.1741 - val_accuracy: 0.4632 - val_loss: 1.4705
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 194ms/step - accuracy: 0.5755 - loss: 1.1713 - val_accuracy: 0.4502 - val_loss: 1.4225
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.6363 - loss: 1.0572 - val_accuracy: 0.5281 - val_loss: 1.4643
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.6276 - loss: 1.0375 - val_accuracy: 0.5065 - val_loss: 1.4698
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 194ms/step - accuracy: 0.6319 - loss: 1.0248 - val_accuracy: 0.5108 - val_loss: 1.4019
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.6656 - loss: 0.9393 - val_accuracy: 0.4719 - val_loss: 1.4581
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.6591 - loss: 0.9657 - val_accuracy: 0.4978 - val_loss: 1.5492
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - accuracy: 0.6710 - loss: 0.8752 - val_accuracy: 0.4589 - val_loss: 1.5443
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.6851 - loss: 0.9179 - val_accuracy: 0.5195 - val_loss: 1.4578
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.7514 - loss: 0.7578 - val_accuracy: 0.4805 - val_loss: 1.6575
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 211ms/step - accuracy: 0.7036 - loss: 0.8413 - val_accuracy: 0.4805 - val_loss: 1.6193
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - accuracy: 0.7481 - loss: 0.7122 - val_accuracy: 0.5195 - val_loss: 1.4956
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 194ms/step - accuracy: 0.7590 - loss: 0.6932 - val_accuracy: 0.4459 - val_loss: 1.7791
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 194ms/step - accuracy: 0.7296 - loss: 0.7717 - val_accuracy: 0.4762 - val_loss: 1.5349
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.7666 - loss: 0.6449 - val_accuracy: 0.5325 - val_loss: 1.5505
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.8035 - loss: 0.5701 - val_accuracy: 0.5368 - val_loss: 1.6389
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.7970 - loss: 0.6252 - val_accuracy: 0.4978 - val_loss: 1.6984
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.7774 - loss: 0.6354 - val_accuracy: 0.5325 - val_loss: 1.7166
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.7926 - loss: 0.6118 - val_accuracy: 0.5152 - val_loss: 1.7426
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 0.7850 - loss: 0.6092 - val_accuracy: 0.4762 - val_loss: 1.7016
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.8208 - loss: 0.5232 - val_accuracy: 0.5195 - val_loss: 1.6509
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.8154 - loss: 0.5254 - val_accuracy: 0.5108 - val_loss: 1.8822
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.8165 - loss: 0.5539 - val_accuracy: 0.5065 - val_loss: 1.7932
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.8295 - loss: 0.4808 - val_accuracy: 0.5238 - val_loss: 1.7938
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.8143 - loss: 0.5239 - val_accuracy: 0.5065 - val_loss: 1.7088
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.7926 - loss: 0.5933 - val_accuracy: 0.5108 - val_loss: 1.5732
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.8165 - loss: 0.5133 - val_accuracy: 0.5195 - val_loss: 1.6730
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.8730 - loss: 0.3968 - val_accuracy: 0.4892 - val_loss: 1.8269
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.8740 - loss: 0.3789 - val_accuracy: 0.5325 - val_loss: 1.8419
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.8719 - loss: 0.3563 - val_accuracy: 0.5411 - val_loss: 1.7792
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.8762 - loss: 0.3677 - val_accuracy: 0.5108 - val_loss: 1.8952
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.8664 - loss: 0.3723 - val_accuracy: 0.5152 - val_loss: 1.8027
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.8426 - loss: 0.4455 - val_accuracy: 0.5022 - val_loss: 1.9055
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.8458 - loss: 0.4677 - val_accuracy: 0.5065 - val_loss: 1.8860
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.8979 - loss: 0.3292 - val_accuracy: 0.5022 - val_loss: 1.8826
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.9283 - loss: 0.2449 - val_accuracy: 0.5325 - val_loss: 2.0614
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.9240 - loss: 0.2199 - val_accuracy: 0.5108 - val_loss: 2.1639

# %% [markdown]
# ### Evaluate Model

# %%
loss, accuracy = model.evaluate(
    x_test,
    y_test
)
print("Test Accuracy:", accuracy)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.4965 - loss: 2.5627
# Test Accuracy: 0.4965277910232544

# %% [markdown]
# ### Predictions

# %%
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step

# %% [markdown]
# ### Accuracy

# %%
acc = accuracy_score(y_true, y_pred)
print("Accuracy:", acc)
print(np.unique(y_pred))
# Out:
# Accuracy: 0.4965277777777778
# [0 1 2 3 4 5 6 7]

# %% [markdown]
# ### Precision

# %%
precision = precision_score(
    y_true,
    y_pred,
    average='weighted'
)
print("Precision:", precision)
# Out:
# Precision: 0.4917604230234601

# %% [markdown]
# ### Recall

# %%
recall = recall_score(
    y_true,
    y_pred,
    average='weighted'
)
print("Recall:", recall)
# Out:
# Recall: 0.4965277777777778

# %% [markdown]
# ### F1 Score

# %%
f1 = f1_score(
    y_true,
    y_pred,
    average='weighted'
)
print("F1 Score:", f1)
# Out:
# F1 Score: 0.49237708803006414

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=emotion_names,
    yticklabels=emotion_names
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()
